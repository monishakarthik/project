# %%
import numpy as np # linear algebra
import pandas as pd # data processing,

# %%
df = pd.read_csv('food 2.csv')
df.head(10)
# Out:
#      Category               Description  Nutrient Data Bank Number  \
# 0      BUTTER          BUTTER,WITH SALT                       1001
# 1      BUTTER  BUTTER,WHIPPED,WITH SALT                       1002
# 2  BUTTER OIL      BUTTER OIL,ANHYDROUS                       1003
# 3      CHEESE               CHEESE,BLUE                       1004
# 4      CHEESE              CHEESE,BRICK                       1005
# 5      CHEESE               CHEESE,BRIE                       1006
# 6      CHEESE          CHEESE,CAMEMBERT                       1007
# 7      CHEESE            CHEESE,CARAWAY                       1008
# 8      CHEESE            CHEESE,CHEDDAR                       1009
# 9      CHEESE           CHEESE,CHESHIRE                       1010
#
#    Data.Alpha Carotene  Data.Ash  Data.Beta Carotene  Data.Beta Cryptoxanthin  \
# 0                    0      2.11                 158                        0
# ...

# %%
df.shape
# Out:
# (7413, 48)

# %%
df.isnull().sum()
# Out:
# Category                                                      0
# Description                                                   0
# Nutrient Data Bank Number                                     0
# Data.Alpha Carotene                                           0
# Data.Ash                                                      0
# Data.Beta Carotene                                            0
# Data.Beta Cryptoxanthin                                       0
# Data.Carbohydrate                                             0
# Data.Cholesterol                                              0
# Data.Choline                                                  0
# Data.Fiber                                                    0
# Data.Kilocalories                                             0
# Data.Lutein and Zeaxanthin                                    0
# Data.Lycopene                                                 0
# Data.Manganese                                                0
# ...

# %%
#we cannot impute values based on mean, median, mode etc, so it's better to drop missing values
#because food is a sensitive area, we should drop missing values

df = df.dropna(axis = 1)

# %%
df.shape  #new shape has 4303 rows,
            #48 columns, it's enough for exploratory data analysis
# Out:
# (7413, 46)

# %%
df.head()
# Out:
#      Category               Description  Nutrient Data Bank Number  \
# 0      BUTTER          BUTTER,WITH SALT                       1001
# 1      BUTTER  BUTTER,WHIPPED,WITH SALT                       1002
# 2  BUTTER OIL      BUTTER OIL,ANHYDROUS                       1003
# 3      CHEESE               CHEESE,BLUE                       1004
# 4      CHEESE              CHEESE,BRICK                       1005
#
#    Data.Alpha Carotene  Data.Ash  Data.Beta Carotene  Data.Beta Cryptoxanthin  \
# 0                    0      2.11                 158                        0
# 1                    0      2.11                 158                        0
# 2                    0      0.00                 193                        0
# 3                    0      5.11                  74                        0
# 4                    0      3.18                  76                        0
#
#    Data.Carbohydrate  Data.Cholesterol  Data.Choline  ...  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.Category.nunique()  #unique values
# Out:
# 1183

# %% [raw]
# Lots of duplicate values, we can pork skins are repeated
# more than once, get rid of duplicate values

# %%
df2 = df.groupby(['Category'], as_index = False).mean()
df2.head()
# Out:
#         Category  Nutrient Data Bank Number  Data.Alpha Carotene  Data.Ash  \
# 0        ABALONE                    15155.5                  0.0      1.67
# 1        ABIYUCH                     9427.0                  0.0      0.90
# 2        ACEROLA                     9001.0                  0.0      0.20
# 3  ACEROLA JUICE                     9002.0                  0.0      0.20
# 4    ACORN FLOUR                    12060.0                  0.0      1.69
#
#    Data.Beta Carotene  Data.Beta Cryptoxanthin  Data.Carbohydrate  \
# 0                 0.0                      0.0               8.53
# 1                60.0                      0.0              17.60
# 2                 0.0                      0.0               7.69
# 3               305.0                      0.0               4.80
# 4                 0.0                      0.0              54.65
#
#    Data.Cholesterol  Data.Choline  Data.Fiber  ...  \
# 0              89.5          32.5         0.0  ...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1183 entries, 0 to 1182
# Data columns (total 45 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Category                                     1183 non-null   object
#  1   Nutrient Data Bank Number                    1183 non-null   float64
#  2   Data.Alpha Carotene                          1183 non-null   float64
#  3   Data.Ash                                     1183 non-null   float64
#  4   Data.Beta Carotene                           1183 non-null   float64
#  5   Data.Beta Cryptoxanthin                      1183 non-null   float64
#  6   Data.Carbohydrate                            1183 non-null   float64
#  7   Data.Cholesterol                             1183 non-null   float64
#  8   Data.Choline                                 1183 non-null   float64
# ...

# %%
df2.describe()
# Out:
#        Nutrient Data Bank Number  Data.Alpha Carotene     Data.Ash  \
# count                1183.000000          1183.000000  1183.000000
# mean                16291.291223            29.005664     2.092762
# std                  9736.567584           452.125290     3.753303
# min                  1003.000000             0.000000     0.000000
# 25%                  9643.555842             0.000000     0.850000
# 50%                 15107.500000             0.000000     1.500000
# 75%                 20046.750000             0.000000     2.479457
# max                 93600.000000         14251.000000    99.800000
#
#        Data.Beta Carotene  Data.Beta Cryptoxanthin  Data.Carbohydrate  \
# count         1183.000000              1183.000000        1183.000000
# mean           225.144119                 8.714474          21.185917
# std           1303.453681                64.223291          21.873384
# min              0.000000                 0.000000           0.000000
# ...

# %%
df2[['Category','Data.Carbohydrate', 'Data.Protein']].sort_values('Data.Protein', ascending = False)[:5]
# Out:
#               Category  Data.Carbohydrate  Data.Protein
# 970   SOY PROT ISOLATE           3.202500     85.690000
# 417           GELATINS           0.000000     85.600000
# 1034              Seal           0.000000     82.600000
# 969      SOY PROT CONC          29.076667     59.963333
# 818         PORK SKINS           0.800000     59.600000

# %% [raw]
# Top 3 food category with high protein are Soy Prot Isolate,
# Gelatins, Seal with protein quantity 85.69gm, 85.6 gm and 82.6gm
# respectively

# %%
df2.columns
# Out:
# Index(['Category', 'Nutrient Data Bank Number', 'Data.Alpha Carotene',
#        'Data.Ash', 'Data.Beta Carotene', 'Data.Beta Cryptoxanthin',
#        'Data.Carbohydrate', 'Data.Cholesterol', 'Data.Choline', 'Data.Fiber',
#        'Data.Kilocalories', 'Data.Lutein and Zeaxanthin', 'Data.Lycopene',
#        'Data.Manganese', 'Data.Niacin', 'Data.Pantothenic Acid',
#        'Data.Protein', 'Data.Refuse Percentage', 'Data.Retinol',
#        'Data.Riboflavin', 'Data.Selenium', 'Data.Sugar Total', 'Data.Thiamin',
#        'Data.Water', 'Data.Fat.Monosaturated Fat',
#        'Data.Fat.Polysaturated Fat', 'Data.Fat.Saturated Fat',
#        'Data.Fat.Total Lipid', 'Data.Household Weights.1st Household Weight',
#        'Data.Household Weights.2nd Household Weight',
#        'Data.Major Minerals.Calcium', 'Data.Major Minerals.Copper',
#        'Data.Major Minerals.Iron', 'Data.Major Minerals.Magnesium',
#        'Data.Major Minerals.Phosphorus', 'Data.Major Minerals.Potassium',
# ...

# %%
Minerals = ['Data.Major Minerals.Calcium', 'Data.Major Minerals.Copper',
       'Data.Major Minerals.Iron', 'Data.Major Minerals.Magnesium',
       'Data.Major Minerals.Phosphorus', 'Data.Major Minerals.Potassium',
       'Data.Major Minerals.Sodium', 'Data.Major Minerals.Zinc']
Vitamins = ['Data.Vitamins.Vitamin A - IU', 'Data.Vitamins.Vitamin A - RAE',
       'Data.Vitamins.Vitamin B12', 'Data.Vitamins.Vitamin B6',
       'Data.Vitamins.Vitamin C', 'Data.Vitamins.Vitamin E',
       'Data.Vitamins.Vitamin K']

# %%
sns.pairplot(df2[Minerals])

# %%
sns.heatmap(df2[Minerals].corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
df2[['Category','Data.Carbohydrate', 'Data.Protein']].sort_values('Data.Protein', ascending = False)[:5]
# Out:
#               Category  Data.Carbohydrate  Data.Protein
# 970   SOY PROT ISOLATE           3.202500     85.690000
# 417           GELATINS           0.000000     85.600000
# 1034              Seal           0.000000     82.600000
# 969      SOY PROT CONC          29.076667     59.963333
# 818         PORK SKINS           0.800000     59.600000

# %% [raw]
# Top 3 food category with high protein are Soy Prot Isolate, Gelatins,
# Seal with protein quantity 85.69gm, 85.6 gm and 82.6gm respectively

# %%
df2.columns
# Out:
# Index(['Category', 'Nutrient Data Bank Number', 'Data.Alpha Carotene',
#        'Data.Ash', 'Data.Beta Carotene', 'Data.Beta Cryptoxanthin',
#        'Data.Carbohydrate', 'Data.Cholesterol', 'Data.Choline', 'Data.Fiber',
#        'Data.Kilocalories', 'Data.Lutein and Zeaxanthin', 'Data.Lycopene',
#        'Data.Manganese', 'Data.Niacin', 'Data.Pantothenic Acid',
#        'Data.Protein', 'Data.Refuse Percentage', 'Data.Retinol',
#        'Data.Riboflavin', 'Data.Selenium', 'Data.Sugar Total', 'Data.Thiamin',
#        'Data.Water', 'Data.Fat.Monosaturated Fat',
#        'Data.Fat.Polysaturated Fat', 'Data.Fat.Saturated Fat',
#        'Data.Fat.Total Lipid', 'Data.Household Weights.1st Household Weight',
#        'Data.Household Weights.2nd Household Weight',
#        'Data.Major Minerals.Calcium', 'Data.Major Minerals.Copper',
#        'Data.Major Minerals.Iron', 'Data.Major Minerals.Magnesium',
#        'Data.Major Minerals.Phosphorus', 'Data.Major Minerals.Potassium',
# ...

# %%
sns.pairplot(df2[Vitamins])

# %%
df2.corr().abs()['Data.Cholesterol'].sort_values(ascending = False)
# Out:
# Data.Cholesterol                               1.000000
# Data.Choline                                   0.642541
# Data.Vitamins.Vitamin B12                      0.310935
# Data.Protein                                   0.309677
# Data.Retinol                                   0.290094
# Data.Vitamins.Vitamin A - RAE                  0.246464
# Data.Fat.Saturated Fat                         0.222637
# Data.Carbohydrate                              0.207807
# Data.Fat.Total Lipid                           0.196425
# Data.Riboflavin                                0.188765
# Data.Fat.Monosaturated Fat                     0.174945
# Data.Pantothenic Acid                          0.156908
# Data.Kilocalories                              0.153361
# Data.Fiber                                     0.145939
# Data.Major Minerals.Phosphorus                 0.127428
# Data.Sugar Total                               0.126390
# Data.Selenium                                  0.123922
# ...
